# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellow-py/Data-Analysis-Project/blob/main/DSFE_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('/content/WIDE_2021-01-28_v1.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   iso_code               region_group  ... slevel4_m slevel4_no
# 0      AFG  Central and Southern Asia  ...       NaN        NaN
# 1      AFG  Central and Southern Asia  ...       NaN        NaN
# 2      AFG  Central and Southern Asia  ...       NaN        NaN
# 3      AFG  Central and Southern Asia  ...       NaN        NaN
# 4      AFG  Central and Southern Asia  ...       NaN        NaN
#
# [5 rows x 86 columns]

# %%
data.describe()
# Out:
#                year        grade  ...    slevel4_m   slevel4_no
# count  35900.000000  8016.000000  ...  1335.000000  1335.000000
# mean    2008.813008     5.117889  ...     0.193972   401.199251
# std        4.605921     1.967788  ...     0.150635   664.613315
# min     1999.000000     2.000000  ...     0.007500    30.000000
# 25%     2006.000000     4.000000  ...     0.072300    76.000000
# 50%     2010.000000     4.000000  ...     0.149700   182.000000
# 75%     2012.000000     8.000000  ...     0.292650   447.000000
# max     2017.000000     8.000000  ...     0.659000  6936.000000
#
# [8 rows x 72 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35900 entries, 0 to 35899
# Data columns (total 86 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   iso_code                  35900 non-null  object
#  1   region_group              35900 non-null  object
#  2   income_group              35900 non-null  object
#  3   country                   35900 non-null  object
#  4   survey                    35900 non-null  object
#  5   year                      35900 non-null  int64
#  6   level                     13712 non-null  object
#  7   grade                     8016 non-null   float64
#  8   category                  35899 non-null  object
#  9   Sex                       21466 non-null  object
#  10  Location                  11386 non-null  object
#  11  Wealth                    25805 non-null  object
#  12  Region                    15309 non-null  object
# ...

# %%
data.drop([:, 86056], axis = 0, inplace=True)
# Out:
#   File "<ipython-input-8-3d5ee4a5dead>", line 1
#     data.drop([:, 86056], axis = 0, inplace=True)
#                ^
# SyntaxError: invalid syntax
